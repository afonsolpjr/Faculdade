# %%
file = open("saida.txt")

def cortastr(str):
    start = 0
    result=[]
    for i in range(len(str)):
        if(str[i]==' '):
            value = str[start:i]
            start=i+1
            result.append(value)
    result.append(str[start:])
    result[0]=int(result[0])
    print(result)
    return result

for linha in file.readlines():
        cortastr(linha.strip())
    
teste = "palavra1 teste oi como vc vai"
# Out:
# [2576, 'a']
# [2073, 'que']
# [1973, 'de']
# [1915, 'e']
# [1877, 'o']
# [1110, 'não']
# [918, 'me']
# [913, 'um']
# [696, 'se']
# [682, 'do']
# [617, 'uma']
# [605, 'da']
# [560, 'com']
# [493, 'era']
# [486, 'é']
# [478, 'os']
# [475, 'eu']
# [435, 'as']
# [392, 'mas']
# [361, 'lhe']
# [355, 'ao']
# [325, 'para']
# [323, 'em']
# [284, 'na']
# [277, 'no']
# [271, 'como']
# [261, 'á']
# [257, 'mais']
# [224, 'por']
# [218, 'elle']
# [215, 'a']
# [213, 'ou']
# [212, 'dos']
# [202, 'meu']
# [198, 'capitulo']
# [184, 'virgilia']
# [180, 'disse']
# [174, 'de']
# [170, 'the']
# [170, 'minha']
# [163, 'foi']
# [156, 'ella']
# [153, 'depois']
# [152, 'das']
# [147, 'e']
# [145, 'que']
# [143, 'cousa']
# [141, 'tinha']
# [139, 'muito']
# [137, 'sem']
# [132, 'porque']
# [132, 'o']
# [129, 'olhos']
# [127, 'nos']
# [126, 'nem']
# [117, 'nada']
# [115, 'vida']
# [114, 'outro']
# [113, 'of']
# [111, 'quando']
# [109, 'outra']
# [108, 'tempo']
# [103, 'menos']
# [103, 'casa']
# [101, 'tudo']
# ...
